# %% [markdown]
# # IAR6 Exercise

# %% [markdown]
# $\textbf{Cruise}:$ The robot drives straight forward.
#
# $\textbf{Avoid}:$ If an obstacle is detected on the left side, the robot turns right until the obstacle is no longer detected. If an obstacle is detected on the right side, the robot turns left.
#
# $\textbf{Escape}:$ If a collision is detected, the robot backs up for $t_b = 2~\textrm{s}$. Afterwards, it spins for $t_s = 2~\textrm{s}$.

# %%
import time
from loop_rate_limiters import RateLimiter
import random

# import thymiodirect package
from thymiodirect import Connection 
from thymiodirect import Thymio

# %%
class Cruise:
    def __init__(self, robot):
        self.command = []
        self.robot = robot
        self.driving_factor = 100
        self.threshold = 50
    
    def action(self):
        print("Going Straight")
        self.forwards()
        return True

    def forwards(self):
        self.robot['motor.left.target'] = self.driving_factor
        self.robot['motor.right.target'] = self.driving_factor

class Escape:
    def __init__(self, robot):
        self.command = []
        self.robot = robot
        self.driving_factor = 100
        self.threshold = 200
        self.timer_1 = 0
        self.timer_2 = 0
        self.time_threshold_1 = 2
        self.time_threshold_2 = 4
        self.active = False
        self.direction = "left"

    def action(self):
        if max(robot['prox.ground.reflected'][:2]) > self.threshold:
            if not self.active:
                print("Starting escape")
                self.active = True
                self.timer_1 = time.time()+self.time_threshold_1
                self.timer_2 = time.time()+self.time_threshold_2
                self.direction = random.choice(["left", "right"])
        if self.timer_1 > time.time():
            print("Going Backwards")
            self.backwards()
            return True
        elif self.timer_2 > time.time():
            print(f"Turning {self.direction}")
            self.turn()
            return True
        else:
            self.active = False
            return False

    def turn(self):
        if self.direction == "left":
            self.robot['motor.left.target'] = self.driving_factor
            self.robot['motor.right.target'] = -self.driving_factor
        else:
            self.robot['motor.left.target'] = -self.driving_factor
            self.robot['motor.right.target'] = self.driving_factor
    def backwards(self):
        self.robot['motor.left.target'] = -self.driving_factor
        self.robot['motor.right.target'] = -self.driving_factor

class Avoid:
    def __init__(self, robot):
        self.robot = robot
        self.command = []
        self.driving_factor = 100
        self.threshold = 200
        self.direction = "left"
        
    def action(self):
        if max(robot['prox.horizontal'][:2]) > self.threshold:
            print("Detected obstacle left")
            self.direction = "left"
            self.turn()
        elif max(robot['prox.horizontal'][3:5]) > self.threshold:
            print("Detected obstacle right")
            self.direction = "right"
            self.turn()
        else:
            return False
        return True

    def turn(self):
        if self.direction == "left":
            self.robot['motor.left.target'] = self.driving_factor
            self.robot['motor.right.target'] = -self.driving_factor
        else:
            self.robot['motor.left.target'] = -self.driving_factor
            self.robot['motor.right.target'] = self.driving_factor

# %%
# Set to True to use the Thymio simulator
use_simulator = True

# Sets the rate limiter to control the loop frequency in Hz
rate = RateLimiter(frequency=10.0) 

if use_simulator:
    port = 2001
    th = Thymio(use_tcp=True, host='localhost', tcp_port=port, on_connect=lambda node_id: print(f' Thymio {node_id} is connected'))
else:
    port = Connection.serial_default_port()
    th = Thymio(serial_port=port, on_connect=lambda node_id: print(f' Thymio {node_id} is connected'))

# Connect to Robot
th.connect()
robot = th[th.first_node()]

# Delay to allow robot initialization of all variables
time.sleep(1)
# Out:
#  Thymio 1 is connected

# %%
# Arbiter
behaviors = []
        
start = True


behaviors.append(Escape(robot))
behaviors.append(Avoid(robot))
behaviors.append(Cruise(robot))

# %%
# don't delete the try-finally block, add your code inside the try block
time_counter = time.time()
try:
    # Main loop
    while True:
        if time_counter + 100 < time.time():
            start = False
        if robot["button.forward"] == 1:
            start = True
        if robot["button.center"] == 1:
            start = False
        print(f"{"-"*50}\nRobot at time {time.time()-time_counter} doing: ")
        if start:
            for behavior in behaviors:
                if behavior.action():
                    break
        else:
            robot['motor.left.target'] = 0
            robot['motor.right.target'] = 0
        rate.sleep()
finally:
    robot['motor.left.target'] = 0
    robot['motor.right.target'] = 0
    print("Interrupted")
# Out:
# [loop_rate_limiters] [13:44:50] [warning] rate limiter is late by 14162.5 [ms] (rate_limiter.py:96)
# --------------------------------------------------
# Robot at time 0.0002193450927734375 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.001622915267944336 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.10173797607421875 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.20190167427062988 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.3019754886627197 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.4020383358001709 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.502103328704834 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.6021733283996582 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.7024185657501221 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.802525520324707 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 0.9027655124664307 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.002903699874878 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.102994680404663 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.2032840251922607 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.3035213947296143 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.4035863876342773 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.503817081451416 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.6038849353790283 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.7039766311645508 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.804039478302002 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 1.9042747020721436 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 2.004373073577881 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 2.1046078205108643 doing:
# Going Straight
# --------------------------------------------------
# Robot at time 2.204735279083252 doing:
# Starting escape
# Going Backwards
# --------------------------------------------------
# Robot at time 2.304780960083008 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 2.4048445224761963 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 2.5050623416900635 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 2.605151653289795 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 2.705247163772583 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 2.8053410053253174 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 2.9055747985839844 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.00567626953125 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.1057393550872803 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.205803632736206 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.3058688640594482 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.4059693813323975 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.506039619445801 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.606280565261841 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.706345319747925 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.8065898418426514 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 3.906827926635742 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 4.006892204284668 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 4.1069581508636475 doing:
# Going Backwards
# --------------------------------------------------
# Robot at time 4.20702338218689 doing:
# Turning left
# --------------------------------------------------
# Robot at time 4.3071253299713135 doing:
# Turning left
# --------------------------------------------------
# Robot at time 4.407369375228882 doing:
# Turning left
# --------------------------------------------------
# Robot at time 4.507607460021973 doing:
# Turning left
# --------------------------------------------------
# Robot at time 4.607809066772461 doing:
# Turning left
# --------------------------------------------------
# Robot at time 4.707913398742676 doing:
# Turning left
# --------------------------------------------------
# Robot at time 4.807965517044067 doing:
# Turning left
# --------------------------------------------------
# Robot at time 4.908037424087524 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.0081400871276855 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.108240127563477 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.208362340927124 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.308511734008789 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.408541440963745 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.508605003356934 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.608883380889893 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.7089455127716064 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.809180974960327 doing:
# Turning left
# --------------------------------------------------
# Robot at time 5.909440279006958 doing:
# Turning left
# --------------------------------------------------
# Robot at time 6.009692668914795 doing:
# Turning left
# --------------------------------------------------
# Robot at time 6.109814882278442 doing:
# Turning left
# --------------------------------------------------
# Robot at time 6.209876298904419 doing:
# Going Straight
# Interrupted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 20
#      18             robot['motor.left.target'] = 0
#      19             robot['motor.right.target'] = 0
# ---> 20         rate.sleep()
#      21 finally:
#      22     robot['motor.left.target'] = 0
#
# File ~/PycharmProjects/IAR2025/.venv/lib/python3.12/site-packages/loop_rate_limiters/rate_limiter.py:94, in RateLimiter.sleep(self)
#      92 self.__slack = self.__next_tick - perf_counter()
#      93 if self.__slack > 0.0:
# ---> 94     sleep(self.__slack)
#      95 elif self.__slack < -0.1 * self.period and self.warn:
#      96     logger.warning(
#      97         "%s is late by %.1f [ms]",
#      98         self.name,
#      99         round(-1e3 * self.__slack, 1),
#     100     )
#
# KeyboardInterrupt:
