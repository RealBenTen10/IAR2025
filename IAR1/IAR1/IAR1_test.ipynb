# %% [markdown]
# # Basics of Programming the Thymio II

# %% [markdown]
# As a first introduction to programming the Thymio II robot, we provide example code showing the most important functionalities for the next exercises. To execute the cells, first select the cell you want to execute and then you can press 'Shift+Enter' or press the 'Play' the button. Before executing the cells, **don't forget to run your Webots simulator**. In Webots, click *File > Open World*. Navigate to the folder *IAR1/Worlds* and open *IAR1.wbt*.
#
# First, we import the required libraries and required classes of the *thymiodirect* module.

# %%
# If you have any errors regarding missing libraries, first activate your virtual environment then install the missing library.
import time
from thymiodirect import Connection 
from thymiodirect import Thymio

# %% [markdown]
# If you are running the below code in Webots simulation set the 'use_simulator' variable to 'True'. It will take care of the 'host' and 'port'. If you want to stop the program you can press the 'stop' sign in Jupyter Notebook. It will activate the 'finally' block and set motor values to 0.

# %%
# Set to True to use the Thymio simulator
use_simulator = True

if use_simulator:
    port = 2001
    th = Thymio(use_tcp=True, host='localhost', tcp_port=port, on_connect=lambda node_id: print(f' Thymio {node_id} is connected'))
else:
    port = Connection.serial_default_port()
    th = Thymio(serial_port=port, on_connect=lambda node_id: print(f' Thymio {node_id} is connected'))

# Connect to Robot
th.connect()
robot = th[th.first_node()]

# Delay to allow robot initialization of all variables
time.sleep(1)

try:
    while True:
        robot['motor.left.target'] = 200
        robot['motor.right.target'] = 150
finally:
    robot['motor.left.target'] = 0
    robot['motor.right.target'] = 0
    print("Interrupted")
# Out:
#  Thymio 1 is connected
# Task exception was never retrieved
# future: <Task finished name='Task-123' coro=<Connection.handle_message.<locals>.do_refresh() done, defined at /home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:451> exception=BrokenPipeError(32, 'Broken pipe')>
# Traceback (most recent call last):
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 458, in do_refresh
#     self.get_variables(source_node)
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 580, in get_variables
#     self.send(msg)
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 530, in send
#     raise error
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 525, in send
#     self.io.write(msg.serialize())
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 339, in write
#     self.socket.sendall(b)
# BrokenPipeError: [Errno 32] Broken pipe
# Task exception was never retrieved
# future: <Task finished name='Task-14' coro=<Connection.__init__.<locals>.discover() done, defined at /home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:236> exception=BrokenPipeError(32, 'Broken pipe')>
# Traceback (most recent call last):
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 238, in discover
#     self.handshake()
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 363, in handshake
#     self.list_nodes()
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 543, in list_nodes
#     self.send(msg)
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 530, in send
#     raise error
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 525, in send
#     self.io.write(msg.serialize())
#   File "/home/ben/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py", line 339, in write
#     self.socket.sendall(b)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[2], line 20
#      19 while True:
# ---> 20     robot['motor.left.target'] = 200
#      21     robot['motor.right.target'] = 150
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/thymio.py:194, in Thymio.__getitem__.<locals>.Node.__setitem__(self_node, name, val)
#     193     else:
# --> 194         self.thymio_proxy.connection.set_var(self_node.node_id, name, val)
#     195 except KeyError:
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:629, in Connection.set_var(self, target_node_id, name, val, index)
#     628     node.set_var(name, val, index)
# --> 629 self.set_variables(target_node_id, node.var_offset[name] + index, [val])
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:590, in Connection.set_variables(self, target_node_id, chunk_offset, chunk)
#     589 msg = Message(Message.ID_SET_VARIABLES, self.host_node_id, payload)
# --> 590 self.send(msg)
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:530, in Connection.send(self, msg)
#     529     self.on_comm_error(error)
# --> 530 raise error
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:525, in Connection.send(self, msg)
#     524 try:
# --> 525     self.io.write(msg.serialize())
#     526 except Exception as error:
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:339, in Connection.tcp.<locals>.TCPClientIO.write(self, b)
#     338 def write(self, b):
# --> 339     self.socket.sendall(b)
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# BrokenPipeError                           Traceback (most recent call last)
# Cell In[2], line 23
#      21         robot['motor.right.target'] = 150
#      22 finally:
# ---> 23     robot['motor.left.target'] = 0
#      24     robot['motor.right.target'] = 0
#      25     print("Interrupted")
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/thymio.py:194, in Thymio.__getitem__.<locals>.Node.__setitem__(self_node, name, val)
#     192         self.thymio_proxy.connection.set_var_array(self_node.node_id, name, val)
#     193     else:
# --> 194         self.thymio_proxy.connection.set_var(self_node.node_id, name, val)
#     195 except KeyError:
#     196     raise KeyError(name)
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:629, in Connection.set_var(self, target_node_id, name, val, index)
#     627 with self.input_lock:
#     628     node.set_var(name, val, index)
# --> 629 self.set_variables(target_node_id, node.var_offset[name] + index, [val])
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:590, in Connection.set_variables(self, target_node_id, chunk_offset, chunk)
#     585 payload = Message.uint16array_to_bytes([
#     586     target_node_id,
#     587     chunk_offset
#     588 ] + chunk)
#     589 msg = Message(Message.ID_SET_VARIABLES, self.host_node_id, payload)
# --> 590 self.send(msg)
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:530, in Connection.send(self, msg)
#     528 if self.on_comm_error:
#     529     self.on_comm_error(error)
# --> 530 raise error
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:525, in Connection.send(self, msg)
#     523     print(">", msg)
#     524 try:
# --> 525     self.io.write(msg.serialize())
#     526 except Exception as error:
#     527     self.comm_error = error
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/thymiodirect/connection.py:339, in Connection.tcp.<locals>.TCPClientIO.write(self, b)
#     338 def write(self, b):
# --> 339     self.socket.sendall(b)
#
# BrokenPipeError: [Errno 32] Broken pipe
