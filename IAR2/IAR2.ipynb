# %% [markdown]
# ## Robot
#
# Number UKON6
#
# 206 LAN
#
# IAR2-6 SD Card
#
# http://134.34.225.206:8888/login?next=%2Ftree%3F

# %% [markdown]
# # IAR2 Exercise

# %% [markdown]
# Invented by neuroscientist Valentino Braitenberg, the so-called Braitenberg Vehicles exhibit quite complex behavior while only following simple rules.
# In this exercise, we implement two Braitenberg Vehicles:  **Attractive and Repulsive** and **Indecisive**.
# We choose between the two behaviors by pressing the forward button for  **Attractive and Repulsive** and by pressing the backward button for **Indecisive**. By pressing the center button, we stop the robot.
#
# **Attractive and Repulsive:** When an object approaches the robot from behind, the robot runs away until it is out of range.
#
# **Indecisive:** When the robot does not detect an object with its front sensors, it moves forward. When it detects an object, it moves backward as long as it detects the object.

# %%
import time
from loop_rate_limiters import RateLimiter

# import thymiodirect package
from thymiodirect import Connection 
from thymiodirect import Thymio

# %%
# Set to True to use the Thymio simulator
use_simulator = True

# Sets the rate limiter to control the loop frequency in Hz
rate = RateLimiter(frequency=10.0) 

if use_simulator:
    port = 2001
    th = Thymio(use_tcp=True, host='localhost', tcp_port=port, on_connect=lambda node_id: print(f' Thymio {node_id} is connected'))
else:
    port = Connection.serial_default_port()
    th = Thymio(serial_port=port, on_connect=lambda node_id: print(f' Thymio {node_id} is connected'))

# Connect to Robot
th.connect()
robot = th[th.first_node()]

# Delay to allow robot initialization of all variables
time.sleep(1)

# Initialize state
state = "STOP"
# Out:
#  Thymio 1 is connected

# %%
# don't delete the try-finally block, add your code inside the try block
state = "STOP"
try:
    while True:
        # 2.1: selection mechanism
        if robot["button.forward"] == 1:
            state = "AR"
            print(f"Changed state to {state}")
        if robot["button.left"] == 1:
            state = "INDECISIVE"
            print(f"Changed state to {state}")
        if robot["button.center"] == 1:
            state = "STOP"
            print(f"Changed state to {state}")

        # 2.2: attraction and repulsion
        print(robot["prox.horizontal"])
        if state == "AR":
            print(f"In state: {state}")
            if robot["prox.horizontal"][5] + robot["prox.horizontal"][6] > 10:
                robot['motor.left.target'] = 100
                robot['motor.right.target'] = 100
            else:
                robot['motor.left.target'] = 0
                robot['motor.right.target'] = 0

        # 2.3: indecisive
        elif state == "INDECISIVE":
            print(f"In state: {state}")
            if robot["prox.horizontal"][0] + robot["prox.horizontal"][1] + robot["prox.horizontal"][2] + robot["prox.horizontal"][3] + robot['prox.horizontal'][4] > 10:
                robot['motor.left.target'] = -100
                robot['motor.right.target'] = -100
            else:
                robot['motor.left.target'] = 100
                robot['motor.right.target'] = 100
        else:
            print(f"In state: {state}")
            robot['motor.left.target'] = 0
            robot['motor.right.target'] = 0
        
        rate.sleep()
finally:
    robot['motor.left.target'] = 0
    robot['motor.right.target'] = 0
    print("Interrupted")
# Out:
# [loop_rate_limiters] [13:40:12] [warning] rate limiter is late by 121565.9 [ms] (rate_limiter.py:96)
# 4282
# 4282
# 4285
# 4176
# 4176
# 4025
# 3742
# 3742
# 3361
# 3056
# 2776
# 2603
# 2441
# 2252
# 2122
# 1923
# 1712
# 1539
# 1341
# 557
# Interrupted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 26
#      23             robot['motor.left.target'] = 0
#      24             robot['motor.right.target'] = 0
# ---> 26         rate.sleep()
#      27 finally:
#      28     robot['motor.left.target'] = 0
#
# File ~/PycharmProjects/PythonProject/.venv/lib/python3.12/site-packages/loop_rate_limiters/rate_limiter.py:94, in RateLimiter.sleep(self)
#      92 self.__slack = self.__next_tick - perf_counter()
#      93 if self.__slack > 0.0:
# ---> 94     sleep(self.__slack)
#      95 elif self.__slack < -0.1 * self.period and self.warn:
#      96     logger.warning(
#      97         "%s is late by %.1f [ms]",
#      98         self.name,
#      99         round(-1e3 * self.__slack, 1),
#     100     )
#
# KeyboardInterrupt:
